# %%
# !pip install huggingface_hub
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
rf = Roboflow(api_key="0BYOi2ZYNmZWD4A5fTZ2")
project = rf.workspace("kappsai").project("plate_detection_colombia")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to plate_detection_colombia-1 in yolov8:: 100%|██████████| 2810/2810 [00:01<00:00, 2186.28it/s]

# %%
model = YOLO(r'/MLmodels\Models\pretrainedModel.pt')  # Load your trained model
image = cv2.imread('plate_detection_colombia-1/test/images/5098855267_jpg.rf.22d49ef956833aa08e3e4799f6c1b9d8.jpg')
model.export(format='onnx', dynamic=True, opset=12)
# Run inference on the image
results = model(image)

# Process the results
for result in results:
    boxes = result.boxes.cpu().numpy()  # Get bounding boxes
    for box in boxes:
        # Get box coordinates
        x1, y1, x2, y2 = box.xyxy[0]
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

        # Draw bounding box
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)

        # If you have class names, you can add them to the image
        if box.cls is not None:
            label = f"{result.names[int(box.cls[0])]} {box.conf[0]:.2f}"
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# Save or display the result
cv2.imwrite('output_image.jpg', image)
# Or to display (if running in an environment with GUI):
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)) # Convert BGR to RGB for matplotlib
plt.show()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model = YOLO(r'C:\Users\Asus\PycharmProjects\ParkSideProyect\Models\Models\pretrainedModel.pt')  # Load your trained model
#       2 image = cv2.imread('plate_detection_colombia-1/test/images/5098855267_jpg.rf.22d49ef956833aa08e3e4799f6c1b9d8.jpg')
#       3 model.export(format='onnx', dynamic=True, opset=12)
#
# File ~\PycharmProjects\ParkSideProyect\.venv\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~\PycharmProjects\ParkSideProyect\.venv\Lib\site-packages\ultralytics\engine\model.py:148, in Model.__init__(self, model, task, verbose)
# ...

# %%
results = model.predict(image)
# Out:
# 0: 640x640 1 0, 297.7ms
# Speed: 3.0ms preprocess, 297.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
